# %%
import pandas as pd

# %%
# bucketname.s3.amazonaws.com
# AKIAJCHGZEE3TMITEB2A:77kS6Pz34EqlwZKRxNSYQUJO+cr1RlVbDz2EGUFE@
location = "http://distilTryouts.s3.amazonaws.com/20131201/search_input"
d1 = pd.read_csv(location, "\1", nrows=10)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-4fba05e0267a> in <module>()
#       2 # AKIAJCHGZEE3TMITEB2A:77kS6Pz34EqlwZKRxNSYQUJO+cr1RlVbDz2EGUFE@
#       3 location = "http://distilTryouts.s3.amazonaws.com/20131201/search_input"
# ----> 4 d1 = pd.read_csv(location, "\1", nrows=10)
#
# ...

# %%
import boto as b

# %%
from boto.s3.connection import S3Connection
conn = S3Connection('AKIAJCHGZEE3TMITEB2A', '77kS6Pz34EqlwZKRxNSYQUJO+cr1RlVbDz2EGUFE')

# %%
from boto.s3.connection import Location
print '\n'.join(i for i in dir(Location) if i[0].isupper())
# Out:
# APNortheast
# APSoutheast
# APSoutheast2
# DEFAULT
# EU
# SAEast
# USWest
# USWest2

# %%
#data = conn.get_bucket('distiltryouts.s3.amazonaws.com') # substitute your bucket name here
rs = conn.get_all_buckets()

# %%
len(rs)
for b in rs:
    print b.name
# Out:
# cf-templates-109o9ptn1fwv-us-east-1
# couponcabin_logs
# distil-repo
# distilLogsCustomers
# distilLogsDowJones
# distilLogsManta
# distilTryouts
# distil_ami
# distil_development
# distil_logs
# distil_logs_odesk
# distil_malek
# distil_staging
# distil_support
# s3hub-33fc95ee2ca3d65d59a8642c6e6741e0172a28cb243341fa8b207163c
# shad_deepstore
# shad_parsed
# shadoop
# suhadoop

# %%
b = rs[6]

# %%
# http://stackoverflow.com/questions/19088584/connect-to-bucket-having-uppercase-letter
from boto.s3.connection import OrdinaryCallingFormat
import boto

#conn = S3Connection('AKIAJCHGZEE3TMITEB2A', '77kS6Pz34EqlwZKRxNSYQUJO+cr1RlVbDz2EGUFE')

conn = boto.connect_s3('AKIAJCHGZEE3TMITEB2A', '77kS6Pz34EqlwZKRxNSYQUJO+cr1RlVbDz2EGUFE',calling_format=OrdinaryCallingFormat())

# %%
b = conn.get_bucket('distilTryouts')

# %%
rs = b.list()

for key in rs:
   print key.name
# Out:
# 20131201/search_input/000000
# 20131201/search_input/000001
# 20131201/search_input/000002
# 20131201/search_input/000003
# 20131201/search_input/000004
# 20131201/search_input/000005
# 20131201/search_input/000006
# 20131201/search_input/000007
# 20131201/search_input/000008
# 20131201/search_input/000009
# 20131201/search_input/000010
# 20131201/search_input/000011
# 20131201/search_input/000012
# 20131201/search_input/000013
# 20131201/search_input/000014
# 20131201/search_input/000015
# 20131201/search_input/000016
# 20131201/search_input/000017
# 20131201/search_input/000018
# 20131201/search_input/000019
# 20131201/search_input/000020
# 20131201/search_input/000021
# 20131201/search_input/000022
# 20131201/search_input/000023
# 20131201/search_input/000024
# 20131201/search_input/000025
# 20131201/search_input/000026
# 20131201/search_input/000027
# 20131201_$folder$
# 20131202/search_input/000000
# 20131202/search_input/000001
# 20131202/search_input/000002
# ...

# %%
ddos_days = ["20131220","20131221","20131222","20131229","20131230","20131231"]  # Days which we know there was a DDOS attack
data_files = []
for i,ddos_day in enumerate(ddos_days):
    folder = b.list(prefix = ddos_day + "/search_input/")
    data_files.extend([key.name for key in folder])

# %%
len(data_files)
# Out:
# 426

# %%
folderlist = b.list( prefix="20131206/search_input/" )

# %%
data_files = [key.name for key in folderlist]

# %%
possible_key = b.get_key(data_files[0])

# %%
possible_key.open_read

# %%
from StringIO import StringIO
filepath_or_buffer = StringIO(possible_key.get_contents_as_string())
data_str = pd.read_csv(filepath_or_buffer,"", nrows=1000, header=None, \
                       names=["prim_id","id","distil_domain_id","user_agent","ref","ah","country","violations","total"])

# %%
data_str.describe()
# Out:
#                  id  distil_domain_id           ah    violations        total
# count  1.000000e+03       1000.000000  1000.000000   1000.000000  1000.000000
# mean   1.903372e+09       1201.015000    12.228000    103.648000     9.728000
# std    8.899233e+08        856.024515     6.900263    709.182747    49.137771
# min    1.739409e+07          2.000000     0.000000     -1.000000     1.000000
# 25%    1.439545e+09        575.000000     6.000000      0.000000     1.000000
# 50%    1.541798e+09        575.000000    13.000000      0.000000     1.000000
# 75%    2.914929e+09       2137.000000    18.000000      0.000000     2.000000
# max    3.754223e+09       2321.000000    23.000000  12304.000000   603.000000

# %%
print data_str["total"].sum()
print data_str["total"][(data_str["violations"] > 0) & (data_str["violations"] < 16384)].sum()
# Out:
# 9728
# 501

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data_str["country"].value_counts().plot(kind="bar")
plt.title("Total traffic breakdown")

# %%
data_str[(data_str["violations"] > 0) & (data_str["violations"] < 16384)].country
# Out:
# 0     NaN
# 6     NaN
# 7     NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 52    NaN
# 57    NaN
# 58    NaN
# 60    NaN
# 61    NaN
# ...
# 730    GB
# 731    GB
# 732    GB
# 733    GB
# 767    GB
# 771    GB
# 795    GB
# 816    GB
# 824    GB
# 825    GB
# 835    GB
# 836    GB
# 886    GB
# 887    GB
# 907    KE
# Name: country, Length: 88, dtype: object

# %%
bot_idx = (data_str["violations"] > 0) & (data_str["violations"] < 16384)

# %%
data_str["total"][bot_idx].sum()
# Out:
# 501

# %%
data_str["country"][(data_str["violations"] > 0) & (data_str["violations"] < 16384)].value_counts().plot(kind="bar")

# %%
total_count = data_str["total"].sum()
print total_count
# Out:
# 9728

# %%
total_lines = len(data_str["total"])
print total_lines
# Out:
# 1000

# %%
ah = data_str['ah'].value_counts().sort_index().plot(kind="bar")
plt.title('Is "ah" the hour of the day?')

# %%
data_str[data_str["country"] == 'AT']
# Out:
#    prim_id          id  distil_domain_id  \
# 12     NaN  3003095042               103
# 14     NaN  3003095554               105
# 15     NaN  3003095554               141
# 16     NaN  3003095810               105
#
#                                            user_agent ref  ah country  \
# 12  Pingdom.com_bot_version_1.4_(http://www.pingdo...  \N  22      AT
# 14  Pingdom.com_bot_version_1.4_(http://www.pingdo...  \N  20      AT
# 15  Pingdom.com_bot_version_1.4_(http://www.pingdo...  \N  12      AT
# 16  Pingdom.com_bot_version_1.4_(http://www.pingdo...  \N   3      AT
#
#     violations  total
# 12          -1      1
# 14          -1      1
# 15          -1      1
# 16          -1      2

# %%
# Group by country and access hour. Count the violations
group = data_str.groupby(["country", "ah"])
c_h_sum = group["total"].sum()

# %%
c_h_sum.keys()
# Out:
# MultiIndex
# ...

# %%
c_h_sum[('US',8)]
# Out:
# 28

# %%
# Violations grouped sums
# Group by country and access hour. Count the violations
group = data_str[bot_idx].groupby(["country", "ah"])
c_h_v_sum = group["total"].sum()

# %%
c_h_v_sum.keys()
# Out:
# MultiIndex
# [(u'CZ', 4), (u'CZ', 5), (u'CZ', 10), (u'CZ', 11), (u'CZ', 13), (u'CZ', 18), (u'DK', 8), (u'EU', 5), (u'EU', 8), (u'EU', 9), (u'EU', 12), (u'EU', 14), (u'GB', 0), (u'GB', 1), (u'GB', 2), (u'GB', 4), (u'GB', 5), (u'GB', 6), (u'GB', 7), (u'GB', 8), (u'GB', 9), (u'GB', 10), (u'GB', 11), (u'GB', 12), (u'GB', 14), (u'GB', 15), (u'GB', 16), (u'GB', 17), (u'GB', 21), (u'GB', 22), (u'GB', 23), (u'IN', 2), (u'JP', 15), (u'KE', 19), (u'MY', 12), (u'RU', 7), (u'US', 0), (u'US', 14), (u'US', 21)]

# %%
tmp = c_h_v_sum.to_dict()

# %%
tmp[('CZ',13)]
# Out:
# 2

# %%
# total lines
# sum of "total" values - total number of requests in the file
# Histogram of country of request - country vs. count in a dictionary of some sort.

total_lines = len(data_str)
total_values = data_str["total"].sum()
country_hist = data_str["country"].value_counts().to_dict()

# %%
total_bot_lines = len(data_str[bot_idx])
print total_bot_lines
total_bot_counts = data_str["total"][bot_idx].sum()
print total_bot_counts
bot_country_hist = data_str["country"][bot_idx].value_counts().to_dict()
# Out:
# 88
# 501

# %%
bot_country_hist
# Out:
# {'CZ': 8,
#  'DK': 1,
#  'EU': 5,
#  'GB': 32,
#  'IN': 1,
#  'JP': 1,
#  'KE': 1,
#  'MY': 1,
#  'RU': 1,
#  'US': 3}
